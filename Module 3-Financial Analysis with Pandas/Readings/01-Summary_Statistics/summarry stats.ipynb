# %%
import pandas as pd

goog_df = pd.DataFrame({"AAPL": [1045.85, 1070.08, 1140.99, 1113.65, 1193.32, 1231.54, 1215.00, 1207.15,1248.84, 1166.27, 1138.85, 1003.63, 1080.91]})

goog_df
# Out:
#        AAPL
# 0   1045.85
# 1   1070.08
# 2   1140.99
# 3   1113.65
# 4   1193.32
# 5   1231.54
# 6   1215.00
# 7   1207.15
# 8   1248.84
# 9   1166.27
# 10  1138.85
# 11  1003.63
# 12  1080.91

# %%
# use describe function

goog_df.describe()
# Out:
#               AAPL
# count    13.000000
# mean   1142.775385
# std      76.556568
# min    1003.630000
# 25%    1080.910000
# 50%    1140.990000
# 75%    1207.150000
# max    1248.840000

# %%
# Create a simple line plot
# %matplotlib inline
import pandas as pd
sales_data = pd.DataFrame({"prices": [1, 2, 3, 3, 5, 1]})
sales_data.plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
daily_returns = pd.DataFrame(
    np.random.randn(10, 2),
    index=pd.date_range('1/1/2020', periods=10),
    columns=["AAPL", "GOOG"])
daily_returns.describe()
# Out:
#             AAPL       GOOG
# count  10.000000  10.000000
# mean   -0.252540   0.045065
# std     0.705007   1.035529
# min    -1.364058  -1.658524
# 25%    -0.616704  -0.571783
# 50%    -0.182171   0.121448
# 75%    -0.079551   0.225051
# max     0.979467   1.822773

# %%
daily_returns.plot()
# Out:
# <AxesSubplot:>

# %%
# box plots
daily_returns.plot(kind="box")
