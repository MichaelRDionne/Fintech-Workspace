# %%
from web3 import Web3

# %%
# Import the RPC Provider
from web3 import EthereumTesterProvider

# %%
# Create an instance of Web3
w3 = Web3()

# %%
 
# Set the provider on the Web3 instance

provider = EthereumTesterProvider()

# Update the Web3 instance to include the provider
w3 = Web3(provider)
# Out:
# ---------------------------------------------------------------------------
# DeprecationWarning                        Traceback (most recent call last)
# /var/folders/rx/gc6cx7xx6vg9ddbljytmzcz00000gn/T/ipykernel_93301/2881623698.py in <module>
#       1 # Set the provider on the Web3 instance
#       2
# ----> 3 provider = EthereumTesterProvider()
#       4
#       5 # Update the Web3 instance to include the provider
#
# /opt/anaconda3/envs/dev/lib/python3.9/site-packages/web3/providers/eth_tester/main.py in __init__(self, ethereum_tester, api_endpoints)
#      67     ) -> None:
#      68         # do not import eth_tester until runtime, it is not a default dependency
# ---> 69         from eth_tester import EthereumTester  # noqa: F811
#      70         from eth_tester.backends.base import BaseChainBackend
#      71         if ethereum_tester is None:
#
# /opt/anaconda3/envs/dev/lib/python3.9/site-packages/eth_tester/__init__.py in <module>
# ----> 1 raise DeprecationWarning(
# ...

# %%
# Access information for the most recent block
w3.eth.get_block("latest")
# Out:
# ---------------------------------------------------------------------------
# CannotHandleRequest                       Traceback (most recent call last)
# /var/folders/rx/gc6cx7xx6vg9ddbljytmzcz00000gn/T/ipykernel_93301/3996471556.py in <module>
#       1 # Access information for the most recent block
# ----> 2 w3.eth.get_block("latest")
#
# /opt/anaconda3/envs/dev/lib/python3.9/site-packages/web3/eth.py in get_block(self, block_identifier, full_transactions)
#     688         self, block_identifier: BlockIdentifier, full_transactions: bool = False
#     689     ) -> BlockData:
# --> 690         return self._get_block(block_identifier, full_transactions)
#     691
#     692     get_code: Method[Callable[..., HexBytes]] = Method(
#
# /opt/anaconda3/envs/dev/lib/python3.9/site-packages/web3/module.py in caller(*args, **kwargs)
#      55             return LogFilter(eth_module=module, filter_id=err.filter_id)
# ...

# %%
# Print a list of accounts on the blockchain
print(w3.eth.accounts)
# Out:
# ---------------------------------------------------------------------------
# CannotHandleRequest                       Traceback (most recent call last)
# /var/folders/rx/gc6cx7xx6vg9ddbljytmzcz00000gn/T/ipykernel_65257/1999493348.py in <module>
#       1 # Print a list of accounts on the blockchain
# ----> 2 print(w3.eth.accounts)
#
# /opt/anaconda3/envs/dev/lib/python3.9/site-packages/web3/eth.py in accounts(self)
#     196     @property
#     197     def accounts(self) -> Tuple[ChecksumAddress]:
# --> 198         return self.get_accounts()
#     199
#     200     _block_number: Method[Callable[[], BlockNumber]] = Method(
#
# /opt/anaconda3/envs/dev/lib/python3.9/site-packages/web3/module.py in caller(*args, **kwargs)
#      56             return LogFilter(eth_module=module, filter_id=err.filter_id)
#      57         result_formatters, error_formatters = response_formatters
# ---> 58         result = w3.manager.request_blocking(method_str, params, error_formatters)
# ...
